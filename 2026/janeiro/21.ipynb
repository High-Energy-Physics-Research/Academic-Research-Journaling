# %% [markdown]
# <details>
#   <summary style="text-align:center; font-size:1.05em;">
#     Clique para ver a fórmula e a prova
#   </summary>
#
#   <div style="text-align:center; font-size:1.15em; margin-top:0.4rem;">
#
#   $$
#   \mathrm{Var}(X)=\mathbb{E}[X^2]-\mathbb{E}[X]^2
#   $$
#
#   </div>
#
#   <div>
#
#   **Prova.**
#
#   ...
#
#   </div>
# </details>

# %% [markdown]
# <details>
#   <summary style="text-align:center; font-size:1.1em;">
#     $\mathrm{Var}(X)=\mathbb{E}[X^2]-\mathbb{E}[X]^2$  <!-- inline, não $$ -->
#   </summary>
#
#   <div>
#
#   **Prova.**
#
#   **Passo 1.** Expanda:
#   $$
#   (X-\mu)^2 = X^2 - 2\mu X + \mu^2
#   $$
#
#   **Passo 2.** Linearidade:
#   $$
#   \mathbb{E}[(X-\mu)^2]
#   = \mathbb{E}[X^2] - 2\mu\mathbb{E}[X] + \mu^2
#   $$
#
#   ...
#
#   </div>
# </details>
