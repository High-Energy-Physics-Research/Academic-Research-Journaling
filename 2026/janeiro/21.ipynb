# %% [markdown]
# $$
# \mathrm{Var}(X)=\mathbb{E}[X^2]-\mathbb{E}[X]^2
# $$
#
# <details>
# <summary><b>Prova</b> (clique para abrir)</summary>
#
# **Passo 1.** Expanda:
# $$
# (X-\mu)^2 = X^2 - 2\mu X + \mu^2
# $$
#
# **Passo 2.** Aplique linearidade:
# $$
# \mathbb{E}[(X-\mu)^2]=\mathbb{E}[X^2]-2\mu\mathbb{E}[X]+\mu^2
# $$
#
# ...
# </details>
