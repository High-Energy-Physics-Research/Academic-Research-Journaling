# %%
from pathlib import Path
from IPython.display import HTML


css = Path("../../assets/css/notebook-theme.css").read_text(encoding="utf-8")
HTML(f"<style>{css}</style>")
# Out:
# <style>@import url('https://fonts.googleapis.com/css2?family=Sevillana&display=swap');
#
# :root{
#   --nb-font: "Sevillana", cursive;
# }
#
# /* Markdown renderizado */
# .rendered_html {
#   font-family: 'Sevillana', cursive !important;
#   font-size: 22px;
#   line-height: 1.6;
#   color: #2c2c2c;
# }
#
# /* Parágrafos e listas */
# .rendered_html p,
# .rendered_html li {
#   font-family: 'Sevillana', cursive !important;
# }</style>

# %% [markdown]
# <div class="nb-body">
#
# Em fluidos relativísticos, a dinâmica macroscópica é descrita pela conservação do tensor energia-momento,
# $$
# \partial_\mu T^{\mu\nu} = 0,
# $$
# onde
# $$
# T^{\mu\nu} = (\varepsilon + p) u^\mu u^\nu - p\, g^{\mu\nu} + \pi^{\mu\nu}.
# $$
# Aqui, $\varepsilon$ é a densidade de energia no referencial local do fluido, $p$ a pressão,
# $u^\mu$ o quadrivetor velocidade normalizado por $u^\mu u_\mu = 1$,
# e $\pi^{\mu\nu}$ representa correções dissipativas associadas à viscosidade de cisalhamento e volume.
# No regime ideal, $\pi^{\mu\nu} = 0$, enquanto teorias hidrodinâmicas de segunda ordem
# introduzem equações de relaxação para garantir causalidade e estabilidade.
# </div>

# %% [markdown]
# <div style="
#     font-family: 'Georgia', serif;
#     font-size: 22px;
#     color: #7a2c2c;
# ">
# Este é um texto com uma fonte diferente ✨
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Patrick+Hand&display=swap" rel="stylesheet">
#
# <div style="
#     font-family: 'Patrick Hand', cursive;
#     font-size: 20px;
#     line-height: 1.6;
#     color: #2c2c2c;
# ">
# Hoje estou organizando minhas ideias como se fosse um caderno de verdade.
# Nada de paper, nada de formalismo excessivo — só pensamento fluindo ✍️
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Handlee&display=swap" rel="stylesheet">
#
# <div style="
#     font-family: 'Handlee', cursive;
#     font-size: 20px;
#     line-height: 1.7;
#     color: #243447;
# ">
# Anotar é pensar devagar.
# Aqui eu posso errar, voltar, rabiscar ideias.
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@500&display=swap" rel="stylesheet">
#
# <div style="
#     font-family: 'Caveat', cursive;
#     font-size: 22px;
#     color: #5a3e36;
# ">
# ⚠️ dúvida aqui: isso vale fora do regime perturbativo?
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Patrick+Hand&family=Caveat:wght@500&display=swap" rel="stylesheet">
#
# <div style="
#     font-family: 'Patrick Hand', cursive;
#     font-size: 20px;
#     line-height: 1.6;
# ">
#
# ### Aula – Introdução à Relatividade
#
# A ideia central é que as equações de Maxwell já contêm a relatividade.
#
# <div style="
#     font-family: 'Caveat', cursive;
#     margin-top: 12px;
#     color: #7a3b2e;
# ">
# 👉 lembrar de revisar a dedução com mais calma
# </div>
#
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Patrick+Hand&display=swap" rel="stylesheet">
#
# <div style="
#   font-family: 'Patrick Hand', cursive;
#   font-size: 20px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
# Em fluidos relativísticos, a hidrodinâmica descreve o comportamento coletivo de sistemas
# fortemente interagentes a partir de quantidades macroscópicas como densidade de energia,
# pressão e velocidade do fluido. A conservação local dessas quantidades codifica,
# de forma efetiva, a dinâmica microscópica subjacente, mesmo quando o sistema está
# fora do equilíbrio estrito.
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Square+Peg&display=swap" rel="stylesheet">
#
# <div style="
#   font-family: 'Square Peg', cursive;
#   font-size: 24px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
# Observação pessoal: a validade da descrição hidrodinâmica depende da separação
# entre escalas microscópicas e macroscópicas. Quando isso falha, a intuição
# do fluido começa a quebrar.
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Allison&display=swap" rel="stylesheet">
#
# <div style="
#   font-family: 'Allison', cursive;
#   font-size: 26px;
#   line-height: 1.5;
#   color: #2c2c2c;
# ">
# Em fluidos relativísticos, a hidrodinâmica descreve o comportamento coletivo de sistemas
# fortemente interagentes a partir de quantidades macroscópicas como densidade de energia
# e pressão.
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Reenie+Beanie&display=swap" rel="stylesheet">
#
# <div style="
#   font-family: 'Reenie Beanie', cursive !important;
#   font-size: 22px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
# Em fluidos relativísticos, a hidrodinâmica descreve o comportamento coletivo de sistemas
# fortemente interagentes a partir de quantidades macroscópicas como densidade de energia,
# pressão e velocidade do fluido. A conservação local dessas quantidades reflete,
# de maneira efetiva, a física microscópica do sistema.
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Patrick+Hand&display=swap" rel="stylesheet">
#
# <div style="
#   font-family: 'Patrick Hand', cursive !important;
#   font-size: 20px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
#
# Partimos da conservação local do tensor energia–momento,
# que pode ser escrita como
#
# </div>
#
# $$
# \partial_\mu T^{\mu\nu} = 0.
# $$
#
# <div style="
#   font-family: 'Patrick Hand', cursive !important;
#   font-size: 20px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
#
# Para um fluido ideal relativístico, o tensor energia–momento é dado por
#
# </div>
#
# $$
# T^{\mu\nu} = (\varepsilon + p) u^\mu u^\nu - p\, g^{\mu\nu}.
# $$
#
# <div style="
#   font-family: 'Patrick Hand', cursive !important;
#   font-size: 20px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
#
# Projetando a equação de conservação ao longo do quadrivetor velocidade,
# obtém-se a equação de conservação de energia,
#
# </div>
#
# $$
# u_\nu \partial_\mu T^{\mu\nu}
# = u^\mu \partial_\mu \varepsilon
# + (\varepsilon + p)\, \partial_\mu u^\mu = 0.
# $$
#
# <div style="
#   font-family: 'Patrick Hand', cursive !important;
#   font-size: 20px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
#
# No referencial local do fluido, essa equação assume uma forma particularmente
# intuitiva: a variação temporal da densidade de energia é governada pela expansão
# do fluido, codificada no divergente do campo de velocidades.
#
# </div>
#
# $$
# \frac{d\varepsilon}{d\tau}
# = -(\varepsilon + p)\, \nabla_\mu u^\mu.
# $$
#
# <div style="
#   font-family: 'Patrick Hand', cursive !important;
#   font-size: 20px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
#
# Em situações com simetria adequada, como expansão longitudinal unidimensional,
# essa equação pode ser integrada explicitamente, fornecendo a dependência
# da densidade de energia com o tempo próprio do fluido.
#
# </div>
#
# $$
# \varepsilon(\tau)
# = \varepsilon_0
# \exp\!\left(
# -\int_{\tau_0}^{\tau}
# (\varepsilon + p)\, \nabla_\mu u^\mu \, d\tau'
# \right).
# $$
#
# <div style="
#   font-family: 'Patrick Hand', cursive;
#   font-size: 20px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
#
# Essa forma deixa claro como a hidrodinâmica relativística traduz,
# em linguagem macroscópica, a dinâmica microscópica do sistema.
#
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Reenie+Beanie&display=swap" rel="stylesheet">
#
# <div style="
#   font-family: 'Reenie Beanie', cursive;
#   font-size: 22px;
#   line-height: 1.6;
#   color: #2c2c2c;
# ">
#
# Em fluidos relativísticos, partimos da conservação local do tensor energia–momento,
# expressa pela equação fundamental
# $$
# \partial_\mu T^{\mu\nu} = 0.
# $$
#
# Para um fluido ideal, o tensor energia–momento assume a forma
# $$
# T^{\mu\nu} = (\varepsilon + p)\, u^\mu u^\nu - p\, g^{\mu\nu},
# $$
# onde $\varepsilon$ é a densidade de energia, $p$ a pressão e $u^\mu$ o quadrivetor
# velocidade, normalizado por $u^\mu u_\mu = 1$.
#
# Projetando a equação de conservação ao longo de $u_\nu$, obtemos
# $$
# u_\nu \partial_\mu T^{\mu\nu}
# = u^\mu \partial_\mu \varepsilon
# + (\varepsilon + p)\, \partial_\mu u^\mu = 0.
# $$
#
# Definindo a derivada convectiva ao longo da linha de mundo do fluido como
# $d/d\tau = u^\mu \partial_\mu$, a equação acima pode ser reescrita como
# $$
# \frac{d\varepsilon}{d\tau}
# = -(\varepsilon + p)\, \nabla_\mu u^\mu.
# $$
#
# Em uma expansão longitudinal simples, como no caso de Bjorken,
# o divergente do campo de velocidades é dado por $\nabla_\mu u^\mu = 1/\tau$,
# de modo que a equação de conservação de energia se reduz a
# $$
# \frac{d\varepsilon}{d\tau}
# = -\frac{\varepsilon + p}{\tau}.
# $$
#
# Assumindo uma equação de estado do tipo $p = c_s^2\, \varepsilon$,
# essa equação diferencial pode ser integrada diretamente,
# $$
# \int_{\varepsilon_0}^{\varepsilon(\tau)}
# \frac{d\varepsilon'}{\varepsilon' (1 + c_s^2)}
# =
# -\int_{\tau_0}^{\tau} \frac{d\tau'}{\tau'}.
# $$
#
# O resultado da integração fornece a dependência explícita da densidade de energia
# com o tempo próprio,
# $$
# \varepsilon(\tau)
# = \varepsilon_0
# \left( \frac{\tau_0}{\tau} \right)^{1 + c_s^2}.
# $$
#
# Essa expressão deixa claro como a expansão do fluido governa o resfriamento
# do sistema em hidrodinâmica relativística.
#
# </div>

# %% [markdown]
# <div class="nota">
# ⚡ Nota: aqui eu estou assumindo simetria de Bjorken e $c_s^2$ constante.
# </div>
