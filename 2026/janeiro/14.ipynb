# %% [markdown]
# ## Eventos

# %% [markdown]
# - [13th International Conference on Hard and Electromagnetic Probes of High-Energy Nuclear Collisions](https://indico.cern.ch/event/1428985/)

# %% [markdown]
# ## Conceitos
#
# 1. [Hadrons de alto momento](#hadrons-de-alto-momento)
# 2. [Regime perturbativo](#regime-perturbativo)
# 3. [Regime não perturbativo](#regime-nao-perturbativo)

# %% [markdown]
# <div class="font-sevillana">
#
# ### Hadrons de alto momento
#
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Sevillana&display=swap" rel="stylesheet">
#
#
# <div style="
#   font-family: 'Sevillana', cursive;
#   font-size: 20px;
#   line-height: 1.5;
#   color: #2c2c2c;
# ">
#
# ### Regime perturbativo
#
# </div>

# %% [markdown]
# <link href="https://fonts.googleapis.com/css2?family=Sevillana&display=swap" rel="stylesheet">
#
#
# <div style="
#   font-family: 'Sevillana', cursive;
#   font-size: 20px;
#   line-height: 1.5;
#   color: #2c2c2c;
# ">
#
# ### Regime nao perturbativo
#
# </div>

# %%
from pathlib import Path
from IPython.display import HTML

css = Path("../../assets/teste.css").read_text(encoding="utf-8")
print(css)
HTML(f"<style>{css}</style>")
# Out:
# /* carregar fontes UMA vez */
# @import url("https://fonts.googleapis.com/css2?family=Sevillana&display=swap");
# @import url("https://fonts.googleapis.com/css2?family=Inter:wght@400;600&display=swap");
#
# /* ===== classes de fonte ===== */
#
# .font-sevillana{
#   font-family: "Sevillana", cursive;
#   font-size: 20px;
#   line-height: 1.5;
#   color: #2c2c2c;
# }
#
# .font-inter{
#   font-family: "Inter", system-ui, -apple-system, "Segoe UI", Roboto, Arial, sans-serif;
#   font-size: 16px;
#   line-height: 1.55;
#   color: #222;
# }
# <style>/* carregar fontes UMA vez */
# @import url("https://fonts.googleapis.com/css2?family=Sevillana&display=swap");
# @import url("https://fonts.googleapis.com/css2?family=Inter:wght@400;600&display=swap");
#
# /* ===== classes de fonte ===== */
#
# .font-sevillana{
#   font-family: "Sevillana", cursive;
#   font-size: 20px;
#   line-height: 1.5;
#   color: #2c2c2c;
# }
#
# .font-inter{
# ...
