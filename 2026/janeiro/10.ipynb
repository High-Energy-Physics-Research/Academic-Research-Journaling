# %% [markdown]
# [Gaussian Processes](https://drive.google.com/file/d/1KkmOahqH7bFVoezHCaarPlqPn0o8Kcvl/view?usp=sharing)

# %% [markdown]
# [Gaussian Process from scratch 1/3](https://peterroelants.github.io/posts/gaussian-process-tutorial/)

# %% [markdown]
# [The kernel cookbook](https://www.cs.toronto.edu/~duvenaud/cookbook/)

# %% [markdown]
# [Gaussian Process Models](https://towardsdatascience.com/gaussian-process-models-7ebce1feb83d/)

# %% [markdown]
# [Fitting Deep Gaussian Process via Hamiltonian Monte Carlo](https://towardsdatascience.com/fitting-deep-gaussian-process-via-hamiltonian-monte-carlo-641725b70514/)

# %% [markdown]
# [Gaussian Process Kernels](https://towardsdatascience.com/gaussian-process-kernels-96bafb4dd63e/)

# %% [markdown]
# [Forecasting new COVID19 cases in Portugal using Gaussian Processes](https://towardsdatascience.com/forecasting-new-covid19-cases-in-portugal-using-gaussian-processes-1956d3315beb/)

# %% [markdown]
# [Unknown Knowns, Bayesian Inference, and structured Gaussian Processes](https://towardsdatascience.com/unknown-knowns-bayesian-inference-and-structured-gaussian-processes-why-domain-scientists-know-4659b7e924a4/)
